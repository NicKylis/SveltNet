# %% [markdown]
# <h1><center>Lightweight class classification model SveltNet</center></h1>

# %% [markdown]
# In this project we will attempt to build a model that is as accurate as possible with a parameter amount at around 100 thousand parameters. As the amount is very low, we will refrain from most usual architecture methods. First of all lets import the required libraries.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.layers import Conv2D, ReLU, MaxPooling2D, UpSampling2D, Dropout, BatchNormalization, Flatten, Dense, Conv2DTranspose, GlobalAveragePooling2D, DepthwiseConv2D
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# We will now create our datasets. We will utilize light data augmentation. The datasets we will test our algorithm are the following:
# - The MNIST dataset
# - The fashion MNIST dataset
# - The cifar10 dataset
# We create a function to load them according to the option we choose for our ease.

# %%
def get_dataset(train_generator, batch_size=32, val_split=0.2, random_state=42, option='MNIST'):
    data = ''
    if(option == 'MNIST'):
        data = tf.keras.datasets.mnist
    elif(option == 'fashionMNIST'):
        data = tf.keras.datasets.fashion_mnist
    elif(option == 'cifar10'):
        data = tf.keras.datasets.cifar10
        
    (x_train, y_train), (x_test, y_test) = data.load_data()

    if option != 'cifar10':
        x_train = x_train.reshape(-1, 28, 28, 1).astype("float32") / 255.0
        x_test = x_test.reshape(-1, 28, 28, 1).astype("float32") / 255.0
    else:
        x_train = x_train.astype("float32") / 255.0
        x_test = x_test.astype("float32") / 255.0
    #Split data to train and valitation
    x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = val_split, random_state=random_state)

    num_classes = 10  # MNIST has 10 classes (digits 0-9)
    y_train = to_categorical(y_train, num_classes)
    y_val = to_categorical(y_val, num_classes)
    y_test = to_categorical(y_test, num_classes)

    #Use default ImageDataGenerator for inmutable images
    val_test_generator = ImageDataGenerator()
    train_gen = train_generator.flow(x_train, y_train, batch_size=batch_size)
    val_gen = val_test_generator.flow(x_val, y_val, batch_size=batch_size)
    test_gen = val_test_generator.flow(x_test, y_test, batch_size=batch_size, shuffle=False)

    return train_gen, val_gen, test_gen, y_test

# %% [markdown]
# We then create the image generators. We will use a 20% train/validation data split and 5 types of transformation for data augmenting.

# %%
train_generator = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.15,
    height_shift_range=0.15,
    shear_range=0.2,
    zoom_range=0.2)

train_data_mnist, val_data_mnist, test_data_mnist, y_true_mnist = get_dataset(train_generator, batch_size=64, val_split=0.2, random_state=42, option='MNIST')
train_data_fashion_mnist, val_data_fashion_mnist, test_data_fashion_mnist, y_true_fashion_mnist = get_dataset(train_generator, batch_size=64, val_split=0.2, random_state=42, option='fashionMNIST')
train_data_cifar10, val_data_cifar10, test_data_cifar10, y_true_cifar10 = get_dataset(train_generator, batch_size=64, val_split=0.2, random_state=42, option='cifar10')

# %% [markdown]
# We now create the model's architecture and layers. As we are pressed for parameters(and size), we will decide to use 5 layers of 2 DepthWiseConv2D filters followed by a conventional convolutional layer. That way we both have depth and keep the size low. We also set the optimizer to start at a higher amount than the usual (2e-3 instead of 1e-3). This will help mainly for our more complex datasets, namely the cifar dataset and a little bit for our fashion MNIST dataset. Finally,  as a loss function we use categorical crossentropy, which is the most common loss function for these kind of models. We add label smoothing in order to refrain from making our model too certain on its wrong decisions.

# %%
def create_model(option='MNIST'):
    model = keras.Sequential()
    if(option=='MNIST' or option=='fashionMNIST'):  
        model.add(Conv2D(16, (5, 5), strides=(1, 1), activation=None, padding='same', input_shape=(28, 28, 1)))
    else:
        model.add(Conv2D(16, (5, 5), strides=(1, 1), activation=None, padding='same', input_shape=(32, 32, 3)))
    model.add(BatchNormalization())
    model.add(ReLU())

    model.add(DepthwiseConv2D((3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(ReLU())
    
    model.add(DepthwiseConv2D((3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(ReLU())
    
    model.add(Conv2D(32, (3, 3), padding='same', activation=None))
    model.add(BatchNormalization())
    model.add(ReLU())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.2))
    
    model.add(DepthwiseConv2D((3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(ReLU())
    
    model.add(DepthwiseConv2D((3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(ReLU())

    model.add(Conv2D(64, (3, 3), padding='same', activation=None))
    model.add(BatchNormalization())
    model.add(ReLU())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.2))

    model.add(DepthwiseConv2D((3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(ReLU())
    
    model.add(DepthwiseConv2D((3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(ReLU())

    model.add(Conv2D(64, (3, 3), padding='same', activation=None))
    model.add(BatchNormalization())
    model.add(ReLU())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.2))

    model.add(DepthwiseConv2D((3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(ReLU())
    
    model.add(DepthwiseConv2D((3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(ReLU())

    model.add(Conv2D(64, (3, 3), padding='same', activation=None))
    model.add(BatchNormalization())
    model.add(ReLU())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.2))

    model.add(DepthwiseConv2D((3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(ReLU())
    
    model.add(DepthwiseConv2D((3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(ReLU())

    model.add(GlobalAveragePooling2D())
    model.add(Dropout(0.3))
    model.add(Dense(10, activation='softmax')) 

    optimizer = Adam(learning_rate=2e-3)
    loss_fn = CategoricalCrossentropy(label_smoothing=0.1)
    model.compile(optimizer=optimizer,
                  loss=loss_fn,
                  metrics=['accuracy', 'Precision', 'Recall'])
    model.summary()

    return model

model_mnist = create_model(option='MNIST')
model_fashion_mnist = create_model(option='fashionMNIST')
model_cifar10 = create_model(option='cifar10')
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 16)        416
#
#  batch_normalization (BatchN  (None, 28, 28, 16)       64
#  ormalization)
#
#  re_lu (ReLU)                (None, 28, 28, 16)        0
#
#  depthwise_conv2d (Depthwise  (None, 28, 28, 16)       160
#  Conv2D)
#
#  batch_normalization_1 (Batc  (None, 28, 28, 16)       64
#  hNormalization)
#
#  re_lu_1 (ReLU)              (None, 28, 28, 16)        0
#
#  depthwise_conv2d_1 (Depthwi  (None, 28, 28, 16)       160
#  seConv2D)
#
#  batch_normalization_2 (Batc  (None, 28, 28, 16)       64
#  hNormalization)
#
#  re_lu_2 (ReLU)              (None, 28, 28, 16)        0
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 32)        4640
#
#  batch_normalization_3 (Batc  (None, 28, 28, 32)       128
#  hNormalization)
#
#  re_lu_3 (ReLU)              (None, 28, 28, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 32)       0
#  )
#
#  dropout (Dropout)           (None, 14, 14, 32)        0
#
#  depthwise_conv2d_2 (Depthwi  (None, 14, 14, 32)       320
#  seConv2D)
#
#  batch_normalization_4 (Batc  (None, 14, 14, 32)       128
#  hNormalization)
#
#  re_lu_4 (ReLU)              (None, 14, 14, 32)        0
#
#  depthwise_conv2d_3 (Depthwi  (None, 14, 14, 32)       320
#  seConv2D)
#
#  batch_normalization_5 (Batc  (None, 14, 14, 32)       128
#  hNormalization)
#
#  re_lu_5 (ReLU)              (None, 14, 14, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 14, 14, 64)        18496
#
#  batch_normalization_6 (Batc  (None, 14, 14, 64)       256
#  hNormalization)
#
#  re_lu_6 (ReLU)              (None, 14, 14, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 7, 7, 64)          0
#
#  depthwise_conv2d_4 (Depthwi  (None, 7, 7, 64)         640
#  seConv2D)
#
#  batch_normalization_7 (Batc  (None, 7, 7, 64)         256
#  hNormalization)
#
#  re_lu_7 (ReLU)              (None, 7, 7, 64)          0
#
#  depthwise_conv2d_5 (Depthwi  (None, 7, 7, 64)         640
#  seConv2D)
#
#  batch_normalization_8 (Batc  (None, 7, 7, 64)         256
#  hNormalization)
#
#  re_lu_8 (ReLU)              (None, 7, 7, 64)          0
#
#  conv2d_3 (Conv2D)           (None, 7, 7, 64)          36928
#
#  batch_normalization_9 (Batc  (None, 7, 7, 64)         256
#  hNormalization)
#
#  re_lu_9 (ReLU)              (None, 7, 7, 64)          0
#
#  max_pooling2d_2 (MaxPooling  (None, 3, 3, 64)         0
#  2D)
#
#  dropout_2 (Dropout)         (None, 3, 3, 64)          0
#
#  depthwise_conv2d_6 (Depthwi  (None, 3, 3, 64)         640
#  seConv2D)
#
#  batch_normalization_10 (Bat  (None, 3, 3, 64)         256
#  chNormalization)
#
#  re_lu_10 (ReLU)             (None, 3, 3, 64)          0
#
#  depthwise_conv2d_7 (Depthwi  (None, 3, 3, 64)         640
#  seConv2D)
#
#  batch_normalization_11 (Bat  (None, 3, 3, 64)         256
#  chNormalization)
#
#  re_lu_11 (ReLU)             (None, 3, 3, 64)          0
#
#  conv2d_4 (Conv2D)           (None, 3, 3, 64)          36928
#
#  batch_normalization_12 (Bat  (None, 3, 3, 64)         256
#  chNormalization)
#
#  re_lu_12 (ReLU)             (None, 3, 3, 64)          0
#
#  max_pooling2d_3 (MaxPooling  (None, 1, 1, 64)         0
#  2D)
#
#  dropout_3 (Dropout)         (None, 1, 1, 64)          0
#
#  depthwise_conv2d_8 (Depthwi  (None, 1, 1, 64)         640
#  seConv2D)
#
#  batch_normalization_13 (Bat  (None, 1, 1, 64)         256
#  chNormalization)
#
#  re_lu_13 (ReLU)             (None, 1, 1, 64)          0
#
#  depthwise_conv2d_9 (Depthwi  (None, 1, 1, 64)         640
#  seConv2D)
#
#  batch_normalization_14 (Bat  (None, 1, 1, 64)         256
#  chNormalization)
#
#  re_lu_14 (ReLU)             (None, 1, 1, 64)          0
#
#  global_average_pooling2d (G  (None, 64)               0
#  lobalAveragePooling2D)
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 10)                650
#
# =================================================================
# Total params: 105,738
# Trainable params: 104,298
# Non-trainable params: 1,440
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 28, 28, 16)        416
#
#  batch_normalization_15 (Bat  (None, 28, 28, 16)       64
#  chNormalization)
#
#  re_lu_15 (ReLU)             (None, 28, 28, 16)        0
#
#  depthwise_conv2d_10 (Depthw  (None, 28, 28, 16)       160
#  iseConv2D)
#
#  batch_normalization_16 (Bat  (None, 28, 28, 16)       64
#  chNormalization)
#
#  re_lu_16 (ReLU)             (None, 28, 28, 16)        0
#
#  depthwise_conv2d_11 (Depthw  (None, 28, 28, 16)       160
#  iseConv2D)
#
#  batch_normalization_17 (Bat  (None, 28, 28, 16)       64
#  chNormalization)
#
#  re_lu_17 (ReLU)             (None, 28, 28, 16)        0
#
#  conv2d_6 (Conv2D)           (None, 28, 28, 32)        4640
#
#  batch_normalization_18 (Bat  (None, 28, 28, 32)       128
#  chNormalization)
#
#  re_lu_18 (ReLU)             (None, 28, 28, 32)        0
#
#  max_pooling2d_4 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  dropout_5 (Dropout)         (None, 14, 14, 32)        0
#
#  depthwise_conv2d_12 (Depthw  (None, 14, 14, 32)       320
#  iseConv2D)
#
#  batch_normalization_19 (Bat  (None, 14, 14, 32)       128
#  chNormalization)
#
#  re_lu_19 (ReLU)             (None, 14, 14, 32)        0
#
#  depthwise_conv2d_13 (Depthw  (None, 14, 14, 32)       320
#  iseConv2D)
#
#  batch_normalization_20 (Bat  (None, 14, 14, 32)       128
#  chNormalization)
#
#  re_lu_20 (ReLU)             (None, 14, 14, 32)        0
#
#  conv2d_7 (Conv2D)           (None, 14, 14, 64)        18496
#
#  batch_normalization_21 (Bat  (None, 14, 14, 64)       256
#  chNormalization)
#
#  re_lu_21 (ReLU)             (None, 14, 14, 64)        0
#
#  max_pooling2d_5 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  dropout_6 (Dropout)         (None, 7, 7, 64)          0
#
#  depthwise_conv2d_14 (Depthw  (None, 7, 7, 64)         640
#  iseConv2D)
#
#  batch_normalization_22 (Bat  (None, 7, 7, 64)         256
#  chNormalization)
#
#  re_lu_22 (ReLU)             (None, 7, 7, 64)          0
#
#  depthwise_conv2d_15 (Depthw  (None, 7, 7, 64)         640
#  iseConv2D)
#
#  batch_normalization_23 (Bat  (None, 7, 7, 64)         256
#  chNormalization)
#
#  re_lu_23 (ReLU)             (None, 7, 7, 64)          0
#
#  conv2d_8 (Conv2D)           (None, 7, 7, 64)          36928
#
#  batch_normalization_24 (Bat  (None, 7, 7, 64)         256
#  chNormalization)
#
#  re_lu_24 (ReLU)             (None, 7, 7, 64)          0
#
#  max_pooling2d_6 (MaxPooling  (None, 3, 3, 64)         0
#  2D)
#
#  dropout_7 (Dropout)         (None, 3, 3, 64)          0
#
#  depthwise_conv2d_16 (Depthw  (None, 3, 3, 64)         640
#  iseConv2D)
#
#  batch_normalization_25 (Bat  (None, 3, 3, 64)         256
#  chNormalization)
#
#  re_lu_25 (ReLU)             (None, 3, 3, 64)          0
#
#  depthwise_conv2d_17 (Depthw  (None, 3, 3, 64)         640
#  iseConv2D)
#
#  batch_normalization_26 (Bat  (None, 3, 3, 64)         256
#  chNormalization)
#
#  re_lu_26 (ReLU)             (None, 3, 3, 64)          0
#
#  conv2d_9 (Conv2D)           (None, 3, 3, 64)          36928
#
#  batch_normalization_27 (Bat  (None, 3, 3, 64)         256
#  chNormalization)
#
#  re_lu_27 (ReLU)             (None, 3, 3, 64)          0
#
#  max_pooling2d_7 (MaxPooling  (None, 1, 1, 64)         0
#  2D)
#
#  dropout_8 (Dropout)         (None, 1, 1, 64)          0
#
#  depthwise_conv2d_18 (Depthw  (None, 1, 1, 64)         640
#  iseConv2D)
#
#  batch_normalization_28 (Bat  (None, 1, 1, 64)         256
#  chNormalization)
#
#  re_lu_28 (ReLU)             (None, 1, 1, 64)          0
#
#  depthwise_conv2d_19 (Depthw  (None, 1, 1, 64)         640
#  iseConv2D)
#
#  batch_normalization_29 (Bat  (None, 1, 1, 64)         256
#  chNormalization)
#
#  re_lu_29 (ReLU)             (None, 1, 1, 64)          0
#
#  global_average_pooling2d_1   (None, 64)               0
#  (GlobalAveragePooling2D)
#
#  dropout_9 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 105,738
# Trainable params: 104,298
# Non-trainable params: 1,440
# _________________________________________________________________
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 32, 32, 16)        1216
#
#  batch_normalization_30 (Bat  (None, 32, 32, 16)       64
#  chNormalization)
#
#  re_lu_30 (ReLU)             (None, 32, 32, 16)        0
#
#  depthwise_conv2d_20 (Depthw  (None, 32, 32, 16)       160
#  iseConv2D)
#
#  batch_normalization_31 (Bat  (None, 32, 32, 16)       64
#  chNormalization)
#
#  re_lu_31 (ReLU)             (None, 32, 32, 16)        0
#
#  depthwise_conv2d_21 (Depthw  (None, 32, 32, 16)       160
#  iseConv2D)
#
#  batch_normalization_32 (Bat  (None, 32, 32, 16)       64
#  chNormalization)
#
#  re_lu_32 (ReLU)             (None, 32, 32, 16)        0
#
#  conv2d_11 (Conv2D)          (None, 32, 32, 32)        4640
#
#  batch_normalization_33 (Bat  (None, 32, 32, 32)       128
#  chNormalization)
#
#  re_lu_33 (ReLU)             (None, 32, 32, 32)        0
#
#  max_pooling2d_8 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  dropout_10 (Dropout)        (None, 16, 16, 32)        0
#
#  depthwise_conv2d_22 (Depthw  (None, 16, 16, 32)       320
#  iseConv2D)
#
#  batch_normalization_34 (Bat  (None, 16, 16, 32)       128
#  chNormalization)
#
#  re_lu_34 (ReLU)             (None, 16, 16, 32)        0
#
#  depthwise_conv2d_23 (Depthw  (None, 16, 16, 32)       320
#  iseConv2D)
#
#  batch_normalization_35 (Bat  (None, 16, 16, 32)       128
#  chNormalization)
#
#  re_lu_35 (ReLU)             (None, 16, 16, 32)        0
#
#  conv2d_12 (Conv2D)          (None, 16, 16, 64)        18496
#
#  batch_normalization_36 (Bat  (None, 16, 16, 64)       256
#  chNormalization)
#
#  re_lu_36 (ReLU)             (None, 16, 16, 64)        0
#
#  max_pooling2d_9 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  dropout_11 (Dropout)        (None, 8, 8, 64)          0
#
#  depthwise_conv2d_24 (Depthw  (None, 8, 8, 64)         640
#  iseConv2D)
#
#  batch_normalization_37 (Bat  (None, 8, 8, 64)         256
#  chNormalization)
#
#  re_lu_37 (ReLU)             (None, 8, 8, 64)          0
#
#  depthwise_conv2d_25 (Depthw  (None, 8, 8, 64)         640
#  iseConv2D)
#
#  batch_normalization_38 (Bat  (None, 8, 8, 64)         256
#  chNormalization)
#
#  re_lu_38 (ReLU)             (None, 8, 8, 64)          0
#
#  conv2d_13 (Conv2D)          (None, 8, 8, 64)          36928
#
#  batch_normalization_39 (Bat  (None, 8, 8, 64)         256
#  chNormalization)
#
#  re_lu_39 (ReLU)             (None, 8, 8, 64)          0
#
#  max_pooling2d_10 (MaxPoolin  (None, 4, 4, 64)         0
#  g2D)
#
#  dropout_12 (Dropout)        (None, 4, 4, 64)          0
#
#  depthwise_conv2d_26 (Depthw  (None, 4, 4, 64)         640
#  iseConv2D)
#
#  batch_normalization_40 (Bat  (None, 4, 4, 64)         256
#  chNormalization)
#
#  re_lu_40 (ReLU)             (None, 4, 4, 64)          0
#
#  depthwise_conv2d_27 (Depthw  (None, 4, 4, 64)         640
#  iseConv2D)
#
#  batch_normalization_41 (Bat  (None, 4, 4, 64)         256
#  chNormalization)
#
#  re_lu_41 (ReLU)             (None, 4, 4, 64)          0
#
#  conv2d_14 (Conv2D)          (None, 4, 4, 64)          36928
#
#  batch_normalization_42 (Bat  (None, 4, 4, 64)         256
#  chNormalization)
#
#  re_lu_42 (ReLU)             (None, 4, 4, 64)          0
#
#  max_pooling2d_11 (MaxPoolin  (None, 2, 2, 64)         0
#  g2D)
#
#  dropout_13 (Dropout)        (None, 2, 2, 64)          0
#
#  depthwise_conv2d_28 (Depthw  (None, 2, 2, 64)         640
#  iseConv2D)
#
#  batch_normalization_43 (Bat  (None, 2, 2, 64)         256
#  chNormalization)
#
#  re_lu_43 (ReLU)             (None, 2, 2, 64)          0
#
#  depthwise_conv2d_29 (Depthw  (None, 2, 2, 64)         640
#  iseConv2D)
#
#  batch_normalization_44 (Bat  (None, 2, 2, 64)         256
#  chNormalization)
#
#  re_lu_44 (ReLU)             (None, 2, 2, 64)          0
#
#  global_average_pooling2d_2   (None, 64)               0
#  (GlobalAveragePooling2D)
#
#  dropout_14 (Dropout)        (None, 64)                0
#
#  dense_2 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 106,538
# Trainable params: 105,098
# Non-trainable params: 1,440
# _________________________________________________________________

# %% [markdown]
# We also create custom scheduler and callback functions.

# %%
lr_scheduler_mnist = ReduceLROnPlateau(monitor='loss', patience=3, factor=0.5, min_lr=5e-5)
lr_scheduler_fashion_mnist = ReduceLROnPlateau(monitor='loss', patience=3, factor=0.5, min_lr=5e-5)
lr_scheduler_cifar10 = ReduceLROnPlateau(monitor='loss', patience=3, factor=0.5, min_lr=5e-5)
#callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=10, restore_best_weights=True)

# %% [markdown]
# We will now train our models. We will use a higher amount of epochs for our cifar10 dataset, as it is trained more slowly. NOTE: If more time is given all models except the standard MNIST model can be further trained for more accuracy.

# %%
history_cifar10 = model_cifar10.fit(train_data_cifar10,
         validation_data=val_data_cifar10,
         epochs=80,
         batch_size=64,
         shuffle=True
         ,callbacks=[lr_scheduler_cifar10])
# Out:
# Epoch 1/80
# 625/625 [==============================] - 20s 28ms/step - loss: 1.9310 - accuracy: 0.3237 - precision: 0.6015 - recall: 0.0530 - val_loss: 1.8786 - val_accuracy: 0.3681 - val_precision: 0.5936 - val_recall: 0.0682 - lr: 0.0020
# Epoch 2/80
# 625/625 [==============================] - 18s 28ms/step - loss: 1.6955 - accuracy: 0.4517 - precision: 0.6948 - recall: 0.1648 - val_loss: 2.3243 - val_accuracy: 0.3224 - val_precision: 0.4077 - val_recall: 0.2376 - lr: 0.0020
# Epoch 3/80
# 625/625 [==============================] - 17s 28ms/step - loss: 1.5835 - accuracy: 0.5105 - precision: 0.7366 - recall: 0.2514 - val_loss: 1.6056 - val_accuracy: 0.4809 - val_precision: 0.6552 - val_recall: 0.3116 - lr: 0.0020
# Epoch 4/80
# 625/625 [==============================] - 18s 28ms/step - loss: 1.4977 - accuracy: 0.5557 - precision: 0.7655 - recall: 0.3149 - val_loss: 1.4554 - val_accuracy: 0.5714 - val_precision: 0.7358 - val_recall: 0.4230 - lr: 0.0020
# Epoch 5/80
# 625/625 [==============================] - 19s 30ms/step - loss: 1.4434 - accuracy: 0.5829 - precision: 0.7770 - recall: 0.3595 - val_loss: 1.3328 - val_accuracy: 0.6243 - val_precision: 0.8223 - val_recall: 0.4405 - lr: 0.0020
# Epoch 6/80
# 625/625 [==============================] - 17s 28ms/step - loss: 1.3940 - accuracy: 0.6090 - precision: 0.7901 - recall: 0.3960 - val_loss: 1.4227 - val_accuracy: 0.5870 - val_precision: 0.7850 - val_recall: 0.4063 - lr: 0.0020
# Epoch 7/80
# 625/625 [==============================] - 17s 28ms/step - loss: 1.3598 - accuracy: 0.6265 - precision: 0.8020 - recall: 0.4254 - val_loss: 1.2646 - val_accuracy: 0.6516 - val_precision: 0.8160 - val_recall: 0.4825 - lr: 0.0020
# Epoch 8/80
# 625/625 [==============================] - 18s 29ms/step - loss: 1.3317 - accuracy: 0.6420 - precision: 0.8089 - recall: 0.4482 - val_loss: 1.2105 - val_accuracy: 0.6817 - val_precision: 0.8673 - val_recall: 0.4915 - lr: 0.0020
# Epoch 9/80
# 625/625 [==============================] - 17s 28ms/step - loss: 1.3085 - accuracy: 0.6526 - precision: 0.8156 - recall: 0.4657 - val_loss: 1.3074 - val_accuracy: 0.6388 - val_precision: 0.8024 - val_recall: 0.4774 - lr: 0.0020
# Epoch 10/80
# 625/625 [==============================] - 29s 47ms/step - loss: 1.0141 - accuracy: 0.7901 - precision: 0.8873 - recall: 0.6785 - val_loss: 0.9463 - val_accuracy: 0.8062 - val_precision: 0.9067 - val_recall: 0.6972 - lr: 1.2500e-04
# Epoch 80/80
# 625/625 [==============================] - 27s 43ms/step - loss: 1.0152 - accuracy: 0.7895 - precision: 0.8842 - recall: 0.6753 - val_loss: 0.9461 - val_accuracy: 0.8096 - val_precision: 0.9080 - val_recall: 0.6978 - lr: 6.2500e-05

# %%
history_fashion_mnist = model_fashion_mnist.fit(train_data_fashion_mnist,
         validation_data=val_data_fashion_mnist,
         epochs=60,
         batch_size=64,
         shuffle=True
         ,callbacks=[lr_scheduler_fashion_mnist])
# Out:
# Epoch 1/60
# 750/750 [==============================] - 38s 48ms/step - loss: 1.3693 - accuracy: 0.6086 - precision: 0.8411 - recall: 0.3937 - val_loss: 1.0171 - val_accuracy: 0.7601 - val_precision: 0.8831 - val_recall: 0.6398 - lr: 0.0020
# Epoch 2/60
# 750/750 [==============================] - 25s 33ms/step - loss: 1.1111 - accuracy: 0.7313 - precision: 0.8713 - recall: 0.5700 - val_loss: 1.0063 - val_accuracy: 0.7727 - val_precision: 0.8305 - val_recall: 0.7117 - lr: 0.0020
# Epoch 3/60
# 750/750 [==============================] - 14s 19ms/step - loss: 1.0489 - accuracy: 0.7669 - precision: 0.8817 - recall: 0.6284 - val_loss: 0.9222 - val_accuracy: 0.8134 - val_precision: 0.8731 - val_recall: 0.7506 - lr: 0.0020
# Epoch 4/60
# 750/750 [==============================] - 14s 18ms/step - loss: 1.0094 - accuracy: 0.7891 - precision: 0.8898 - recall: 0.6629 - val_loss: 0.9061 - val_accuracy: 0.8132 - val_precision: 0.8768 - val_recall: 0.7490 - lr: 0.0020
# Epoch 5/60
# 750/750 [==============================] - 13s 18ms/step - loss: 0.9861 - accuracy: 0.8036 - precision: 0.8892 - recall: 0.6881 - val_loss: 0.8904 - val_accuracy: 0.8353 - val_precision: 0.8888 - val_recall: 0.7794 - lr: 0.0020
# Epoch 6/60
# 750/750 [==============================] - 13s 18ms/step - loss: 0.9635 - accuracy: 0.8132 - precision: 0.8944 - recall: 0.7075 - val_loss: 0.8448 - val_accuracy: 0.8482 - val_precision: 0.9029 - val_recall: 0.7908 - lr: 0.0020
# Epoch 7/60
# 750/750 [==============================] - 14s 18ms/step - loss: 0.9476 - accuracy: 0.8227 - precision: 0.8975 - recall: 0.7204 - val_loss: 0.8653 - val_accuracy: 0.8366 - val_precision: 0.8941 - val_recall: 0.7742 - lr: 0.0020
# Epoch 8/60
# 750/750 [==============================] - 13s 18ms/step - loss: 0.9404 - accuracy: 0.8251 - precision: 0.9004 - recall: 0.7256 - val_loss: 1.0325 - val_accuracy: 0.7742 - val_precision: 0.8894 - val_recall: 0.6827 - lr: 0.0020
# Epoch 9/60
# 750/750 [==============================] - 13s 17ms/step - loss: 0.9274 - accuracy: 0.8319 - precision: 0.9038 - recall: 0.7349 - val_loss: 0.8230 - val_accuracy: 0.8611 - val_precision: 0.9087 - val_recall: 0.8140 - lr: 0.0020
# 750/750 [==============================] - 13s 17ms/step - loss: 0.8117 - accuracy: 0.8880 - precision: 0.9310 - recall: 0.8256 - val_loss: 0.7466 - val_accuracy: 0.8962 - val_precision: 0.9312 - val_recall: 0.8661 - lr: 0.0010
# Epoch 57/60
# 750/750 [==============================] - 13s 17ms/step - loss: 0.8127 - accuracy: 0.8857 - precision: 0.9301 - recall: 0.8226 - val_loss: 0.7538 - val_accuracy: 0.8902 - val_precision: 0.9223 - val_recall: 0.8652 - lr: 0.0010
# Epoch 58/60
# 750/750 [==============================] - 13s 17ms/step - loss: 0.8116 - accuracy: 0.8881 - precision: 0.9312 - recall: 0.8253 - val_loss: 0.7597 - val_accuracy: 0.8916 - val_precision: 0.9252 - val_recall: 0.8581 - lr: 0.0010
# Epoch 59/60
# 750/750 [==============================] - 13s 17ms/step - loss: 0.8080 - accuracy: 0.8895 - precision: 0.9325 - recall: 0.8260 - val_loss: 0.7596 - val_accuracy: 0.8868 - val_precision: 0.9182 - val_recall: 0.8602 - lr: 0.0010
# Epoch 60/60
# 750/750 [==============================] - 13s 17ms/step - loss: 0.8048 - accuracy: 0.8908 - precision: 0.9335 - recall: 0.8305 - val_loss: 0.7456 - val_accuracy: 0.8986 - val_precision: 0.9271 - val_recall: 0.8739 - lr: 0.0010

# %%
history_mnist = model_mnist.fit(train_data_mnist,
         validation_data=val_data_mnist,
         epochs=50,
         batch_size=64,
         shuffle=True
         ,callbacks=[lr_scheduler_mnist])
# Out:
# Epoch 1/50
# 750/750 [==============================] - 15s 19ms/step - loss: 1.1521 - accuracy: 0.7493 - precision: 0.9286 - recall: 0.5977 - val_loss: 0.7950 - val_accuracy: 0.8953 - val_precision: 0.9468 - val_recall: 0.8351 - lr: 0.0020
# Epoch 2/50
# 750/750 [==============================] - 14s 18ms/step - loss: 0.7487 - accuracy: 0.9354 - precision: 0.9667 - recall: 0.8811 - val_loss: 0.6584 - val_accuracy: 0.9465 - val_precision: 0.9650 - val_recall: 0.9247 - lr: 0.0020
# Epoch 3/50
# 750/750 [==============================] - 13s 17ms/step - loss: 0.7037 - accuracy: 0.9515 - precision: 0.9747 - recall: 0.9081 - val_loss: 0.5881 - val_accuracy: 0.9769 - val_precision: 0.9856 - val_recall: 0.9635 - lr: 0.0020
# Epoch 4/50
# 750/750 [==============================] - 12s 17ms/step - loss: 0.6865 - accuracy: 0.9572 - precision: 0.9777 - recall: 0.9190 - val_loss: 0.5783 - val_accuracy: 0.9783 - val_precision: 0.9864 - val_recall: 0.9696 - lr: 0.0020
# Epoch 5/50
# 750/750 [==============================] - 14s 19ms/step - loss: 0.6659 - accuracy: 0.9648 - precision: 0.9821 - recall: 0.9332 - val_loss: 0.5644 - val_accuracy: 0.9844 - val_precision: 0.9893 - val_recall: 0.9788 - lr: 0.0020
# Epoch 6/50
# 750/750 [==============================] - 13s 17ms/step - loss: 0.6588 - accuracy: 0.9684 - precision: 0.9831 - recall: 0.9366 - val_loss: 0.5806 - val_accuracy: 0.9833 - val_precision: 0.9871 - val_recall: 0.9788 - lr: 0.0020
# Epoch 42/50
# 750/750 [==============================] - 13s 18ms/step - loss: 0.5964 - accuracy: 0.9906 - precision: 0.9946 - recall: 0.9753 - val_loss: 0.5405 - val_accuracy: 0.9940 - val_precision: 0.9960 - val_recall: 0.9931 - lr: 2.5000e-04
# Epoch 43/50
# 750/750 [==============================] - 14s 18ms/step - loss: 0.5956 - accuracy: 0.9905 - precision: 0.9947 - recall: 0.9742 - val_loss: 0.5426 - val_accuracy: 0.9949 - val_precision: 0.9964 - val_recall: 0.9937 - lr: 2.5000e-04
# Epoch 44/50
# 750/750 [==============================] - 14s 19ms/step - loss: 0.5953 - accuracy: 0.9909 - precision: 0.9951 - recall: 0.9766 - val_loss: 0.5424 - val_accuracy: 0.9946 - val_precision: 0.9961 - val_recall: 0.9934 - lr: 2.5000e-04
# Epoch 45/50
# 750/750 [==============================] - 13s 18ms/step - loss: 0.5964 - accuracy: 0.9904 - precision: 0.9946 - recall: 0.9760 - val_loss: 0.5404 - val_accuracy: 0.9943 - val_precision: 0.9959 - val_recall: 0.9933 - lr: 2.5000e-04
# Epoch 46/50
# 750/750 [==============================] - 13s 18ms/step - loss: 0.5971 - accuracy: 0.9904 - precision: 0.9945 - recall: 0.9751 - val_loss: 0.5421 - val_accuracy: 0.9945 - val_precision: 0.9958 - val_recall: 0.9934 - lr: 2.5000e-04
# Epoch 47/50
# 750/750 [==============================] - 15s 20ms/step - loss: 0.5971 - accuracy: 0.9907 - precision: 0.9948 - recall: 0.9745 - val_loss: 0.5428 - val_accuracy: 0.9943 - val_precision: 0.9959 - val_recall: 0.9934 - lr: 2.5000e-04
# Epoch 48/50
# 750/750 [==============================] - 13s 18ms/step - loss: 0.5951 - accuracy: 0.9917 - precision: 0.9957 - recall: 0.9759 - val_loss: 0.5413 - val_accuracy: 0.9941 - val_precision: 0.9956 - val_recall: 0.9931 - lr: 1.2500e-04
# Epoch 49/50
# 750/750 [==============================] - 12s 17ms/step - loss: 0.5956 - accuracy: 0.9912 - precision: 0.9953 - recall: 0.9760 - val_loss: 0.5408 - val_accuracy: 0.9945 - val_precision: 0.9961 - val_recall: 0.9930 - lr: 1.2500e-04
# Epoch 50/50
# 750/750 [==============================] - 14s 18ms/step - loss: 0.5939 - accuracy: 0.9915 - precision: 0.9956 - recall: 0.9773 - val_loss: 0.5397 - val_accuracy: 0.9947 - val_precision: 0.9960 - val_recall: 0.9932 - lr: 1.2500e-04

# %% [markdown]
# We now save our models in all kinds of ways in order to ensure we do not lose their weights (it has happened before so better safe than sorry). In the repository the .keras models with the optimizer loaded in will be available for use.

# %%
model_mnist.save('models/model_mnist.h5')
model_mnist.save('models/model_mnist.keras')
model_fashion_mnist.save('models/model_fashion_mnist.h5')
model_fashion_mnist.save('models/model_fashion_mnist.keras')
model_cifar10.save('models/model_cifar10.h5')
model_cifar10.save('models/model_cifar10.keras')

model_mnist.save_weights('models/mnist_weights.h5')
model_mnist.save_weights('models/mnist_weights.ckpt')
model_fashion_mnist.save_weights('models/fashion_mnist_weights.h5')
model_fashion_mnist.save_weights('models/fashion_mnist_weights.ckpt')
model_cifar10.save_weights('models/cifar_weights.h5')
model_cifar10.save_weights('models/cifar_weights.ckpt')

# %% [markdown]
# Lets now visualize our accuracy and loss along our epochs.

# %%
def plot_data_by_epoch(history):
    epochs = range(1, len(history.history['accuracy']) + 1)
    loss = history.history['loss']
    v_loss = history.history['val_loss']
    acc = history.history['accuracy']
    v_acc = history.history['val_accuracy']
    
    fig, ax = plt.subplots(1, 2, figsize=(15,9))
    ax[0].plot(epochs, acc, 'b-', linewidth=2, label='Accuracy')
    ax[0].plot(epochs, v_acc, 'r-', linewidth=2, label='Val Accuracy')
    ax[0].set_title('Evolution of accuracy and validation accuracy over epochs')
    ax[0].set_xlabel('Epoch')
    ax[0].set_ylabel('Accuracy')
    ax[0].legend(loc='best')
    
    ax[1].plot(epochs, loss, 'b-', linewidth=2, label='Loss')
    ax[1].plot(epochs, v_loss, 'r-', linewidth=2, label='Val Loss')
    ax[1].set_title('Evolution of loss and validation loss over epochs')
    ax[1].set_xlabel('Epoch')
    ax[1].set_ylabel('Loss')
    ax[1].legend(loc='best')
    plt.show()

plot_data_by_epoch(history_mnist)
plot_data_by_epoch(history_fashion_mnist)
plot_data_by_epoch(history_cifar10)

# %% [markdown]
# Finally, we need to test the model's accuracy for each class and generally. We will display the most important accuracy metrics along with the confusion matrix. If you did not run the models for training above load the models from here.

# %%
model_mnist = tf.keras.models.load_model('models/model_mnist.keras')
model_fashion_mnist = tf.keras.models.load_model('models/model_fashion_mnist.keras')
model_cifar10 = tf.keras.models.load_model('models/model_cifar10.keras')

# %%
def test_model(model, test_dataset, y_test):
    y_pred = model.predict(test_dataset)
    y_pred_classes = y_pred.argmax(axis=1)  # Convert probabilities to class labels
    y_true = y_test.argmax(axis=1)  # Convert one-hot labels back to class labels

    cm = confusion_matrix(y_true, y_pred_classes)

    plt.figure(figsize=(15, 12))
    sns.heatmap(cm, cmap='Blues', xticklabels=False, yticklabels=False)
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title('Confusion Matrix (EMNIST)')
    plt.show()
    
    print(classification_report(y_true, y_pred_classes))

test_model(model_mnist, test_data_mnist, y_true_mnist)
test_model(model_fashion_mnist, test_data_fashion_mnist, y_true_fashion_mnist)
test_model(model_cifar10, test_data_cifar10, y_true_cifar10)
# Out:
# 157/157 [==============================] - 3s 4ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       980
#            1       1.00      1.00      1.00      1135
#            2       1.00      1.00      1.00      1032
#            3       1.00      1.00      1.00      1010
#            4       1.00      1.00      1.00       982
#            5       0.99      1.00      0.99       892
#            6       1.00      0.99      1.00       958
#            7       0.99      1.00      0.99      1028
#            8       1.00      1.00      1.00       974
#            9       1.00      0.99      0.99      1009
#
#     accuracy                           1.00     10000
#    macro avg       1.00      1.00      1.00     10000
# weighted avg       1.00      1.00      1.00     10000
#
# 157/157 [==============================] - 1s 4ms/step
#               precision    recall  f1-score   support
#
#            0       0.88      0.79      0.84      1000
#            1       1.00      0.97      0.98      1000
#            2       0.92      0.80      0.86      1000
#            3       0.92      0.83      0.87      1000
#            4       0.87      0.82      0.84      1000
#            5       0.99      0.98      0.98      1000
#            6       0.60      0.83      0.70      1000
#            7       0.94      0.98      0.96      1000
#            8       0.97      0.99      0.98      1000
#            9       0.98      0.95      0.96      1000
#
#     accuracy                           0.89     10000
#    macro avg       0.91      0.89      0.90     10000
# weighted avg       0.91      0.89      0.90     10000
#
# 157/157 [==============================] - 1s 5ms/step
#               precision    recall  f1-score   support
#
#            0       0.87      0.76      0.81      1000
#            1       0.95      0.90      0.92      1000
#            2       0.83      0.66      0.74      1000
#            3       0.71      0.64      0.67      1000
#            4       0.76      0.79      0.78      1000
#            5       0.81      0.67      0.73      1000
#            6       0.63      0.95      0.76      1000
#            7       0.91      0.77      0.83      1000
#            8       0.79      0.94      0.86      1000
#            9       0.85      0.91      0.88      1000
#
#     accuracy                           0.80     10000
#    macro avg       0.81      0.80      0.80     10000
# weighted avg       0.81      0.80      0.80     10000

# %% [markdown]
# Finally, the most important step: Calculating our model's accuracy on the train data of each dataset.

# %%
def get_model_metrics(model, test_data, model_title='model'):
    res = model.evaluate(test_data)
    loss, acc, prec, rec = res
    print(model_title)
    print(f'The accuracy of the model is{acc}')
    print(f'The loss of the model is {loss}')
    print(f'The precision of the model is{prec}')
    print(f'The recall of the model is {rec}')
    print('-' * 150 + '\n')

get_model_metrics(model_mnist, test_data_mnist,model_title='Model metrics for MNIST dataset')
get_model_metrics(model_fashion_mnist, test_data_fashion_mnist, model_title='Model metrics for the fashion MNIST dataset')
get_model_metrics(model_cifar10, test_data_cifar10, model_title = 'Model metrics for the cifar10 dataset')
# Out:
# 157/157 [==============================] - 1s 6ms/step - loss: 0.5359 - accuracy: 0.9963 - precision: 0.9972 - recall: 0.9947
# Model metrics for MNIST dataset
# The accuracy of the model is0.9962999820709229
# The loss of the model is 0.5359208583831787
# The precision of the model is0.9971929788589478
# The recall of the model is 0.994700014591217
# ------------------------------------------------------------------------------------------------------------------------------------------------------
#
# 157/157 [==============================] - 1s 6ms/step - loss: 0.7564 - accuracy: 0.8945 - precision: 0.9201 - recall: 0.8693
# Model metrics for the fashion MNIST dataset
# The accuracy of the model is0.8945000171661377
# The loss of the model is 0.7564142346382141
# The precision of the model is0.9200888872146606
# The recall of the model is 0.8693000078201294
# ------------------------------------------------------------------------------------------------------------------------------------------------------
#
# 157/157 [==============================] - 1s 7ms/step - loss: 0.9675 - accuracy: 0.7994 - precision: 0.8969 - recall: 0.6822
# Model metrics for the cifar10 dataset
# The accuracy of the model is0.7993999719619751
# The loss of the model is 0.9674921035766602
# The precision of the model is0.8969234824180603
# The recall of the model is 0.682200014591217
# ------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# These are some very promising results. Lets visualize the predictions to get a better understading of what our predictions portray.

# %%
fashion_mnist_label_to_class = {0: 'T-shirt/top', 1: 'Trouser', 2: 'Pullover', 3: 'Dress', 4: 'Coat', 5: 'Sandal', 6: 'Shirt', 7: 'Sneaker', 8: 'Bag', 9: 'Ankle boot'}
cifar10_label_to_class = {0: 'airplane', 1: 'automobile', 2: 'bird', 3: 'cat', 4: 'deer', 5: 'dog', 6: 'frog', 7: 'horse', 8: 'ship', 9: 'truck'}

def showcase_data(model, dataset, convertor=None):
    fig, ax = plt.subplots(8, 4, figsize=(15, 35))
    batch_images, batch_true_labels = next(dataset)
    batch_predictions = model.predict(batch_images)
    batch_true_indices = np.argmax(batch_true_labels, axis=1)
    batch_pred_indices = np.argmax(batch_predictions, axis=1)
    
    for i in range(32):
        ax[i // 4, i % 4].imshow(batch_images[i].squeeze(), cmap='gray')
        ax[i // 4, i % 4].axis('off')
        if convertor is None:
            ax[i // 4, i % 4].set_title(f'Predicted: {batch_pred_indices[i]}')
        else:
            ax[i // 4, i % 4].set_title(f'Predicted: {convertor[batch_pred_indices[i]]}')
    print("The batch's true indices are:")
    print(batch_true_indices)
    print("The batch's predicted indices are:")
    print(batch_pred_indices)
    plt.imshow(batch_images[0].squeeze(), cmap='gray')

showcase_data(model_mnist, test_data_mnist)
# Out:
# 2/2 [==============================] - 1s 9ms/step
# The batch's true indices are:
# [7 2 1 0 4 1 4 9 5 9 0 6 9 0 1 5 9 7 3 4 9 6 6 5 4 0 7 4 0 1 3 1 3 4 7 2 7
#  1 2 1 1 7 4 2 3 5 1 2 4 4 6 3 5 5 6 0 4 1 9 5 7 8 9 3]
# The batch's predicted indices are:
# [7 2 1 0 4 1 4 9 5 9 0 6 9 0 1 5 9 7 3 4 9 6 6 5 4 0 7 4 0 1 3 1 3 4 7 2 7
#  1 2 1 1 7 4 2 3 5 1 2 4 4 6 3 5 5 6 0 4 1 9 5 7 8 9 3]

# %%
showcase_data(model_fashion_mnist, test_data_fashion_mnist, convertor=fashion_mnist_label_to_class)
# Out:
# 2/2 [==============================] - 0s 9ms/step
# The batch's true indices are:
# [9 2 1 1 6 1 4 6 5 7 4 5 7 3 4 1 2 4 8 0 2 5 7 9 1 4 6 0 9 3 8 8 3 3 8 0 7
#  5 7 9 6 1 3 7 6 7 2 1 2 2 4 4 5 8 2 2 8 4 8 0 7 7 8 5]
# The batch's predicted indices are:
# [9 2 1 1 6 1 4 6 5 7 4 5 5 3 4 1 2 4 8 0 2 5 7 5 1 2 6 6 9 3 8 8 3 3 8 0 7
#  5 7 9 6 1 6 7 6 7 2 1 2 6 6 4 5 8 2 2 8 4 8 0 7 7 8 5]

# %%
showcase_data(model_cifar10, test_data_cifar10, convertor=cifar10_label_to_class)
# Out:
# 2/2 [==============================] - 0s 4ms/step
# The batch's true indices are:
# [3 8 8 0 6 6 1 6 3 1 0 9 5 7 9 8 5 7 8 6 7 0 4 9 5 2 4 0 9 6 6 5 4 5 9 2 4
#  1 9 5 4 6 5 6 0 9 3 9 7 6 9 8 0 3 8 8 7 7 4 6 7 3 6 3]
# The batch's predicted indices are:
# [3 8 8 0 6 6 1 6 3 9 0 9 5 7 9 8 5 7 8 6 7 0 4 9 4 4 4 0 9 6 6 5 6 5 9 8 6
#  9 9 5 4 6 5 6 0 9 3 9 7 6 9 8 7 6 8 8 7 3 6 6 7 5 6 3]

# %% [markdown]
# The results are quite good for all 3 datasets tested! The accuracy is very high for such a low amount of trainable parameters and without using a base model to help.
